# %%
import pandas as pd
import numpy as np
import konlpy
from konlpy.tag import Kkma
import re

# %%
df = pd.read_csv('ytn_final.csv', header = None)

# %%
text = df[4][56]

# %%
def endRemove(og_text):
    # Only remove extra information from end of article
    front_text = og_text[:-200]
    end_text = og_text[-200:]
    end_text = re.sub('\(?[0-9A-Za-z]*\@[A-Za-z]+\.[a-z]*\.*[a-z]*\)?', '', end_text) #email removed
    end_text = re.sub('\[[()0-9A-Za-zㄱ-ㅎㅏ-ㅣ가-힣 ]*\] ', '', end_text) #last comments removed
    end_text = re.sub('YTN [가-힣 ]*', '', end_text) #ytn journalist removed
    end_text = re.sub('※ \'[A-Za-zㄱ-ㅎㅏ-ㅣ가-힣 ]*\'', '', end_text) #message removed
    end_text = re.sub('[0-9]+-[0-9]+-[0-9]+', '', end_text) #phone number removed
    new_text = front_text + end_text
    return new_text

# %%
def speakRemove(og_text):
    # Remove any script-like aspects
    text = re.sub('\[앵커\]', '', og_text)
    text = re.sub('\[기자\]', '', text)
    text = re.sub('[\[\]]', '', text)
    return text

# %%
kkma = Kkma()
def text_analysis(text):
    # This will take a slightly long time!!!
    text_1 = endRemove(text)
    text_1 = speakRemove(text_1)
    tokens = kkma.morphs(text_1)
    pos_tokens = kkma.pos(text_1)
    return {'text': text_1, 'tokens': tokens, 'pos': pos_tokens}

# %% [markdown]
# ## Dataset: dictionary
#
# - Dataset['text'] -> list of text strings
# - Dataset['tokens'] -> list of numpy arrays of morpheme tokens
# - Dataset['pos'] -> list of numpy arrays of pos-tagged tokens

# %%
Dataset = {'text': [], 'tokens': [], 'pos': []}
for i, art in enumerate(df[4]):
    result = text_analysis(art)
    Dataset['text'].append(result['text'])
    Dataset['tokens'].append((result['tokens']))
    Dataset['pos'].append((result['pos']))

# %%
print(Dataset['pos'])
# Out:
# [[('음식', 'NNG'), ('을', 'JKO'), ('씹', 'VV'), ('기', 'ETN'), ('어렵', 'VA'), ('ㄴ', 'ETD'), ('노인', 'NNG'), ('은', 'JX'), ('노쇠', 'NNG'), ('위험', 'NNG'), ('이', 'JKS'), ('2.7', 'NR'), ('배', 'NNG'), ('높', 'VA'), ('아', 'ECD'), ('노년기', 'NNG'), ('에', 'JKM'), ('급격', 'XR'), ('하', 'XSA'), ('ㄴ', 'ETD'), ('노쇠', 'NNG'), ('를', 'JKO'), ('막', 'VV'), ('으려', 'ECD'), ('면', 'NNG'), ('평소', 'NNG'), ('치아', 'NNG'), ('건강', 'NNG'), ('을', 'JKO'), ('유지', 'NNG'), ('하', 'XSV'), ('는', 'ETD'), ('것', 'NNB'), ('이', 'JKS'), ('중요', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('것', 'NNB'), ('으로', 'JKM'), ('나타나', 'VV'), ('었', 'EPT'), ('습니다', 'EFN'), ('.', 'SF'), ('서울', 'NNG'), ('아산', 'NNP'), ('병원', 'NNG'), ('노년', 'NNG'), ('내과', 'NNG'), ('정', 'NNG'), ('희원', 'NNG'), (',', 'SP'), ('빛', 'NNG'), ('고을', 'NNG'), ('전', 'NNG'), ('남대', 'NNG'), ('병원', 'NNG'), ('노년', 'NNG'), ('내과', 'NNG'), ('강', 'NNG'), ('민', 'NNG'), ('구', 'NNG'), ('교수', 'NNG'), ('공동', 'NNG'), ('연구', 'NNG'), ('팀', 'NNG'), ('은', 'JX'), ('2016', 'NR'), ('∼', 'SO'), ('2018', 'NR'), ('년', 'NNB'), ('국민', 'NNG'), ('건강', 'NNG'), ('영양', 'NNG'), ('조사', 'NNG'), ('에', 'JKM'), ('참여', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('65', 'NR'), ('세', 'NNM'), ('이상', 'NNG'), ('3', 'NR'), ('천', 'NR'), ('여', 'NR'), ('명', 'NNM'), ('을', 'JKO'), ('대상', 'NNG'), ('으로', 'JKM'), ('노년기', 'NNG'), ('이후', 'NNG'), ('음식', 'NNG'), ('을', 'JKO'), ('씹', 'VV'), ('는', 'ETD'), ('저작', 'NNG'), ('기능', 'NNG'), ('이', 'JKS'), ('노쇠', 'NNG'), ('에', 'JKM'), ('미치', 'VV'), ('는', 'ETD'), ('영향', 'NNG'), ('을', 'JKO'), ('평가', 'NNG'), ('하', 'XSV'), ('었', 'EPT'), ('습니다', 'EFN'), ('.', 'SF'), ('노쇠', 'NNG'), ('는', 'JX'), ('신체', 'NNG'), ('기능', 'NNG'), ('이', 'JKS'), ('급격히', 'MAG'), ('허약', 'NNG'), ('해지', 'VV'), ('어', 'ECS'), ('장애', 'NNG'), ('나', 'JC'), ('입원', 'NNG'), ('가능성', 'NNG'), ('이', 'JKS'), ('커지', 'VV'), ('ㄴ', 'ETD'), ('상태', 'NNG'), ('를', 'JKO'), ('말하', 'VV'), ('ㅂ니다', 'EFN'), ('.', 'SF'), ('그', 'MDT'), ('결과', 'NNG'), ('평소', 'NNG'), ('음식', 'NNG'), ('을', 'JKO'), ('씹', 'VV'), ('는데', 'ECD'), ('어려움', 'NNG'), ('을', 'JKO'), ('호소', 'NNG'), ('하', 'XSV'), ('는', 'ETD'), ('노인', 'NNG'), ('은', 'JX'), ('그렇', 'VA'), ('지', 'ECD'), ('않', 'VXV'), ('은', 'ETD'), ('노인', 'NNG'), ('보다', 'JKM'), ('노쇠', 'NNG'), ('위험', 'NNG'), ('이', 'JKS'), ('2.68', 'NR'), ('배', 'NNG'), ('높', 'VA'), ('은', 'ETD'), ('것', 'NNB'), ('으로', 'JKM'), ('분석', 'NNG'), ('되', 'XSV'), ('었', 'EPT'), ('습니다', 'EFN'), ('.', 'SF'), ('연구', 'NNG'), ('팀', 'NNG'), ('은', 'JX'), ('음식', 'NNG'), ('을', 'JKO'), ('씹', 'VV'), ('는', 'ETD'), ('능력', 'NNG'), ('이', 'JKS'), ('영양', 'NNG'), ('섭취', 'NNG'), ('와', 'JKM'), ('식단', 'NNG'), ('선택', 'NNG'), ('에', 'JKM'), ('크', 'VA'), ('ㄴ', 'ETD'), ('영향', 'NNG'), ('을', 'JKO'), ('끼치', 'VV'), ('기', 'ETN'), ('때문', 'NNB'), ('에', 'JKM'), ('노년기', 'NNG'), ('의', 'JKG'), ('전신', 'NNG'), ('건강', 'NNG'), ('상태', 'NNG'), ('를', 'JKO'), ('파악', 'NNG'), ('하', 'XSV'), ('는', 'ETD'), ('지표', 'NNG'), ('가', 'JKC'), ('되', 'VV'), ('ㄹ', 'ETD'), ('수', 'NNB'), ('있', 'VV'), ('다고', 'EFN'), ('설명', 'NNG'), ('하', 'XSV'), ('었', 'EPT'), ('습니다', 'EFN'), ('.', 'SF'), ('정', 'XPN'), ('희원', 'NNG'), ('교수', 'NNG'), ('는', 'JX'), ('건강', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETD'), ('노년', 'NNG'), ('을', 'JKO'), ('맞', 'VV'), ('으려', 'ECD'), ('면', 'NNG'), ('평소', 'NNG'), ('치아', 'NNG'), ('상태', 'NNG'), ('를', 'JKO'), ('건강', 'NNG'), ('하', 'XSV'), ('게', 'ECD'), ('관리', 'NNG'), ('하', 'XSV'), ('는', 'ETD'), ('것', 'NNB'), ('이', 'JKS'), ('중요', 'NNG'), ('하다', 'NNP'), ('이', 'VCP'), ('면', 'ECE'), ('스', 'VV'), ('어', 'ECS'), ('음식', 'NNG'), ('을', 'JKO'), ('씹', 'VV'), ('는', 'ETD'), ('데', 'NNB'), ('어려움', 'NNG'), ('이', 'JKS'), ('있', 'VA'), ('다면', 'ECE'), ('고령', 'NNG'), ('친화', 'NNG'), ('식품', 'NNG'), ('이나', 'JC'), ('보충제', 'NNG'), ('등', 'NNB'), ('을', 'JKO'), ('통하', 'VV'), ('어', 'ECS'), ('영양분', 'NNG'), ('을', 'JKO'), ('골고루', 'MAG'), ('섭취', 'NNG'), ('하', 'XSV'), ('어', 'ECS'), ('노쇠', 'NNG'), ('를', 'JKO'), ('예방', 'NNG'), ('하', 'XSV'), ('려는', 'ETD'), ('노력', 'NNG'), ('이', 'JKS'), ('필요', 'NNG'), ('하다', 'NNP'), ('이', 'VCP'), ('고', 'ECE'), ('말하', 'VV'), ('었', 'EPT'), ('습니다', 'EFN'), ('.', 'SF'), ('이번', 'NNG'), ('연구', 'NNG ...

# %%
import json

with open("C:/Users/lhi30/Desktop/Writing_Advice/Data/articles_ytn_tokenized.json", "w") as outfile:
    json.dump(Dataset, outfile)

# %%
import json
 
with open("C:/Users/lhi30/Desktop/Writing_Advice/Data/articles_ytn_tokenized.json") as json_file:
    data = json.load(json_file)

# %%
data['pos'][4]
# Out:
# [['교육', 'NNG'],
#  ['단체', 'NNG'],
#  ['들', 'XSN'],
#  ['이', 'JKS'],
#  ['IB', 'OL'],
#  [',', 'SP'],
#  ['국제', 'NNG'],
#  ['바', 'NNG'],
#  ['칼', 'NNG'],
#  ['로', 'JKM'],
#  ['레', 'NNG'],
#  ['아', 'XSN'],
#  ['도입', 'NNG'],
#  ['과', 'JC'],
#  ['자', 'NNG'],
#  ['사고', 'NNG'],
#  ['·', 'SP'],
#  ['특', 'UN'],
#  ['목', 'NNG'],
#  ['고', 'XSN'],
#  ['존치', 'NNG'],
#  [',', 'SP'],
#  ['대학', 'NNG'],
#  ['자율권', 'NNG'],
#  ['확대', 'NNG'],
#  ['기조', 'NNG'],
#  ['가', 'JKS'],
#  ['맞물리', 'VV'],
#  ['면', 'ECE'],
#  [',', 'SP'],
#  ['기존', 'NNG'],
#  ['의', 'JKG'],
#  ['학교', 'NNG'],
#  ['서열', 'NNG'],
#  ['체제', 'NNG'],
#  ['를', 'JKO'],
#  ['강화', 'NNG'],
#  ['하', 'XSV'],
#  ['ㄹ', 'ETD'],
#  ['것', 'NNB'],
#  ['이', 'VCP'],
#  ['라며', 'ECE'],
#  ['교육부', 'NNG'],
#  ['핵심', 'NNG'],
#  ['정책', 'NNG'],
#  ['들', 'XSN'],
#  ['을', 'JKO'],
#  ['비판', 'NNG'],
#  ['하', 'XSV'],
#  ['었', 'EPT'],
#  ['습니다', 'EFN'],
#  ['.', 'SF'],
#  ['사교육', 'NNG'],
#  ['걱정', 'NNG'],
#  ['없', 'VA'],
#  ['는', 'ETD'],
#  ['세상', 'NNG'],
#  ['과', 'JKM'],
#  ['좋', 'VA'],
#  ['은', 'ETD'],
#  ['교사', 'NNG'],
#  ['운동', 'NNG'],
#  [',', 'SP'],
#  ['교육', 'NNG'],
#  ['의', 'JKG'],
#  ['봄', 'NNG'],
#  ['등', 'NNB'],
#  ['교육', 'NNG'],
#  ['단체', 'NNG'],
#  ['3', 'NR'],
#  ['곳', 'NNG'],
#  ['은', 'JX'],
#  ['오늘', 'NNG'],
#  ['서울', 'NNG'],
#  ['용산구', 'NNP'],
#  ['에서', 'JKM'],
#  ['기자', 'NNG'],
#  ['회견', 'NNG'],
#  ['을', 'JKO'],
#  ['열', 'VV'],
#  ['고', 'ECE'],
#  ["'", 'SS'],
#  ['이주호', 'NNG'],
#  ['교육부', 'NNG'],
#  ["'", 'SS'],
#  ['의', 'NNG'],
#  ['10', 'NR'],
#  ['대', 'NNM'],
#  ['교육', 'NNG'],
#  ['개혁', 'NNG'],
#  ['정책', 'NNG'],
#  ['의', 'JKG'],
#  ['평가', 'NNG'],
#  ['결과', 'NNG'],
#  ['를', 'JKO'],
#  ['발표', 'NNG'],
#  ['하', 'XSV'],
#  ['었', 'EPT'],
#  ['습니다', 'EFN'],
#  ['.', 'SF'],
#  ['교육', 'NNG'],
#  ['3', 'NR'],
#  ['단체', 'NNG'],
#  ['는', 'JX'],
#  ["'", 'SS'],
#  ['꺼내', 'VV'],
#  ['는', 'ETD'],
#  ['교육', 'NNG'],
#  ["'", 'SS'],
#  ['을', 'NNG'],
#  ['추구', 'NNG'],
#  ['하', 'XSV'],
#  ['는', 'ETD'],
#  ['IB', 'OL'],
#  ['과정', 'NNG'],
#  ['자체', 'NNG'],
#  ['는', 'JX'],
#  ['훌륭', 'XR'],
#  ['하', 'XSA'],
#  ['지만', 'ECE'],
#  ['기존', 'NNG'],
#  ['의', 'JKG'],
#  ['고교', 'NNG'],
#  ['스', 'VV'],
#  ['어', 'ECS'],
#  ['열화', 'NNG'],
#  ['체제', 'NNG'],
#  ['에서', 'JKM'],
#  ['는', 'JX'],
#  ['일반', 'NNG'],
#  ['고와', 'NNG'],
#  ['자', 'NNG'],
#  ['사고', 'NNG'],
#  [',', 'SP'],
#  ['외고', 'NNG'],
#  ['에서', 'JKM'],
#  ['IB', 'OL'],
#  ['를', 'JKO'],
#  ['운영', 'NNG'],
#  ['하', 'XSV'],
#  ['는', 'ETD'],
#  ['학교', 'NNG'],
#  ['와', 'JKM'],
#  ['그렇', 'VV'],
#  ['지', 'ECD'],
#  ['않', 'VXV'],
#  ['은', 'ETD'],
#  ['학교', 'NNG'],
#  ['로', 'JKM'],
#  ['고교', 'NNG'],
#  ['서열', 'NNG'],
#  ['이', 'JKS'],
#  ['더', 'MAG'],
#  ['세분화', 'NNG'],
#  ['하', 'XSV'],
#  ['ㄹ', 'ETD'],
#  ['것', 'NNB'],
#  ['이', 'VCP'],
#  ['라고', 'ECD'],
#  ['밝히', 'VV'],
#  ['었', 'EPT'],
#  ['습니다', 'EFN'],
#  ['.', 'SF'],
#  ['또', 'MAG'],
#  [',', 'SP'],
#  ['낙후', 'NNG'],
#  ['되', 'XSV'],
#  ['ㄴ', 'ETD'],
#  ['지역', 'NNG'],
#  ['IB', 'OL'],
#  ['고교', 'NNG'],
#  ['가', 'JKS'],
#  ['대입', 'NNG'],
#  ['에서', 'JKM'],
#  ['유리', 'NNG'],
#  ['하', 'XSV'],
#  ['ㄴ', 'ETD'],
#  ['길', 'NNG'],
#  ['을', 'JKO'],
#  ['트', 'VV'],
#  ['어', 'ECS'],
#  ['주', 'VXV'],
#  ['고', 'ECE'],
#  [',', 'SP'],
#  ['특권', 'NNG'],
#  ['학교', 'NNG'],
#  ['들', 'XSN'],
#  ['이', 'JKS'],
#  ['그', 'MDT'],
#  ['길', 'NNG'],
#  ['을', 'JKO'],
#  ['악용', 'NNG'],
#  ['하', 'XSV'],
#  ['어', 'ECS'],
#  ['입시', 'NNG'],
#  ['경쟁', 'NNG'],
#  ['과', 'JC'],
#  ['사교육', 'NNG'],
#  ['이', 'JKS'],
#  ['더', 'MAG'],
#  ['심화', 'NNG'],
#  ['하', 'XSV'],
#  ['ㄹ', 'ETD'],
#  ['것', 'NNB'],
#  ['이', 'VCP'],
#  ['라고', 'ECD'],
#  ['말하', 'VV'],
#  ['었', 'EPT'],
#  ['습니다', 'EFN'],
#  ['.', 'SF'],
#  ['그러', 'VV'],
#  ['면서', 'ECE'],
#  [',', 'SP'],
#  ['초등학교', 'NNG'],
#  ['와', 'JC'],
#  ['중학교', 'NNG'],
#  ['과정', 'NNG'],
#  ['은', 'JX'],
#  ['교육청', 'NNG'],
#  ['자율', 'NNG'],
#  ['로', 'JKM'],
#  ['하', 'VV'],
#  ['되', 'ECD'],
#  [',', 'SP'],
#  ['고등학교', 'NNG'],
#  ['과정', 'NNG'],
#  ['은', 'JX'],
#  ['KB', 'OL'],
#  [',', 'SP'],
#  ['즉', 'MAG'],
#  ['교육부', 'NNG'],
#  ['가', 'JKS'],
#  ['주관', 'NNG'],
#  ['하', 'XSV'],
#  ['는', 'ETD'],
#  ['IB', 'OL'],
#  ['식', 'NNG'],
#  ['교육', 'NNG'],
#  ['체제', 'NNG'],
#  ['로', 'JKM'],
#  ['의', 'JKG'],
#  ['로드', 'NNG'],
#  ['맵', 'VA'],
#  ['을', 'ETD'],
#  ['먼저', 'MAG'],
#  ['신중', 'NNG'],
#  ['하', 'XSV'],
#  ['게', 'ECD'],
#  ['검토', 'NNG'],
#  ['하', 'XSV'],
#  ['ㄴ', 'ETD'],
#  ['뒤', 'NNG'],
#  ['에', 'JKM'],
#  ['추진', 'NNG'],
#  ['여부', 'NNG'],
#  ['를', 'JKO'],
#  ['판단', 'NNG'],
#  ['하', 'XSV'],
#  ['어야', 'ECD'],
#  ['하', 'VV'],
#  ['ㄴ다고', 'ECE'],
#  ['주장', 'NNG'],
#  ['하', 'XSV'],
#  ['었', 'EPT'],
#  ['습니다', 'EFN'],
#  ['.', 'SF'],
#  ['이', 'JKS'],
#  ['들', 'VV'],
#  ['ㄹ', 'ETD'],
#  ['단체', 'NNG'],
#  ['는', 'JX'],
#  ['대학', 'NNG'],
#  ['운영', 'NNG'],
#  ['규제', 'NNG'],
#  ['철폐', 'NNG'],
#  ['정책', 'NNG'],
#  ['과', 'JC'],
#  ['교육', 'NNG'],
#  ['자유', 'NNG'],
#  ['특구', 'NNG'],
#  ['설치', 'NNG'],
#  ['도', 'JX'],
#  ['매우', 'MAG'],
#  ['부정적', 'NNG'],
#  ['으로', 'JKM'],
#  ['평가', 'NNG'],
#  ['하', 'XSV'],
#  ['었', 'EPT'],
#  ['습니다', 'EFN'],
#  ['.', 'SF'],
#  ['학과', 'NNG'],
#  ['신설', 'NNG'],
#  ['과', 'JC'],
#  ['정원', 'NNG'],
#  ['조정', 'NNG'],
#  ['과', 'JKM'],
#  ['관련', 'NNG'],
#  ['하', 'XSV'],
#  ['어', 'ECS'],
#  ['대학', 'NNG'],
#  ['에', 'JKM'],
#  ['자율권', 'NNG'],
#  ['을', 'JKO'],
#  ['부여', 'NNG'],
#  ['하', 'XSV'],
#  ['면서', 'ECE'],
#  ['수도권', 'NNG'],
#  ['쏠리', 'VV'],
#  ['ㅁ', 'ETN'],
#  ['현상', 'NNG'],
#  ['이', 'JKS'],
#  ['심하', 'VA'],
#  ['어', 'ECS'],
#  ['지', 'VXV'],
#  ['고', 'ECE'],
#  ['인기', 'NNG'],
#  ['학과', 'NNG'],
#  ['중심', 'NNG'],
#  ['으로', 'JKM'],
#  ['학과', 'NNG'],
#  ['가', 'JKS'],
#  ['개편', 'NNG'],
#  ['되', 'XSV'],
#  ['는', 'ETD'],
#  ['문제', 'NNG'],
#  ['가', 'JKS'],
#  ['발생', 'NNG'],
#  ['하', 'XSV'],
#  ['ㄹ', 'ETD'],
#  ['거', 'NNB'],
#  ['라고', 'JX'],
#  ['지적', 'NNG'],
#  ['하', 'XSV'],
#  ['었', 'EPT'],
#  ['습니다', 'EFN'],
#  ['.', 'SF'],
#  ['또', 'MAG'],
#  [',', 'SP'],
#  ['이미', 'MAG'],
#  ['경제', 'NNG'],
#  ['자유', 'NNG'],
#  ['구역', 'NNG'],
#  ['내의', 'NNG'],
#  ['고등', 'NNG'],
#  ['외국', 'NNG'],
#  ['교육', 'NNG'],
#  ['기관', 'NNG'],
#  ['설치', 'NNG'],
#  ['는', 'JX'],
#  ['부산', 'NNG'],
#  ['-', 'SW'],
#  ['진하', 'VV'],
#  ['어', 'ECS'],
#  ['독일', 'NNG'],
#  ['FAU', 'OL'],
#  ['(', 'SS'],
#  ['프리드', 'NNG'],
#  ['리', 'NNG'],
#  ['히', 'NNG'],
#  ['알', 'XPN'],
#  ['렉', 'NNG'],
#  ['산', 'XSN'],
#  ['더', 'MAG'],
#  ['대학교', 'NNG'],
#  [')', 'SS'],
#  ['오', 'VV'],
#  ['아', 'ECS'],
#  ['광양만', 'NNG'],
#  ['네덜란드', 'NNG'],
#  ['국제', 'NNG'],
#  ['물류', 'NNG'],
#  ['대가', 'NNG'],
#  ['폐교', 'NNG'],
#  ['하', 'XSV'],
#  ['ㄴ', 'ETD'],
#  ['데', 'NNB'],
#  ['서', 'JKM'],
#  ['보', 'VV'],
#  ['ㄹ', 'ETD'],
#  ['수', 'NNB'],
#  ['있', 'VV'],
#  ['듯', 'ECD'],
#  ['이미', 'MAG'],
#  ['실패', 'NNG'],
#  ['하', 'XSV'],
#  ['ㄴ', 'ETD'],
#  ['정책', 'NNG'],
#  ['이', 'VCP'],
#  ['고', 'ECE'],
#  [',', 'SP'],
#  ['교육', 'NNG'],
#  ['자유', 'NNG'],
#  ['특구', 'NNG'],
#  ['설치', 'NNG'],
#  ['는', 'JX'],
#  ['또', 'MAG'],
#  ['다른', 'MDT'],
#  ['특권', 'NNG'],
#  ['교육', 'NNG'],
#  ['트랙', 'NNG'],
#  ['을', 'JKO'],
#  ['만들', 'VV'],
#  ['는', 'ETD'],
#  ['거', 'NNB'],
#  ['라', 'NNG'],
#  ['며', 'JC'],
#  ['대학', 'NNG'],
#  ['신설', 'NNG'],
#  ['규제', 'NNG'],
#  ['를', 'JKO'],
#  ['엄격히', 'MAG'],
#  ['유지', 'NNG'],
#  ['하', 'XSV'],
#  ['어야', 'ECD'],
#  ['하', 'VV'],
#  ['ㄴ다고', 'ECE'],
#  ['주장', 'NNG'],
#  ['하', 'XSV'],
#  ['었', 'EPT'],
#  ['습니다', 'EFN'],
#  ['.', 'SF']]
